# %% [markdown]
# # Euclidian Error
#
# This notebook will test the accuracy as a function c_s. The paper calls for c_s to be 0.67, but in my experience, that value is too high.

# %%
from test import accuracy
import numpy as np
import matplotlib.pyplot as plt

# %%
def accuracy_vs_cs():
    c_s_values = []
    abs_accuracy_values = []
    rel_accuracy_values = []

    for c_s in np.arange(0, 1, 0.01):
        print(f"Processing c_s = {c_s}")
        c_s_values.append(c_s)
        alg_output_sum, ground_truth_sum, abs_diff, sum_time, table_rows = accuracy.summary_stats(c_s)
        abs_accuracy_values.append(abs_diff)
        rel_accuracy_values.append(alg_output_sum - ground_truth_sum)

    return c_s_values, abs_accuracy_values, rel_accuracy_values

# %%
cs_values, abs_accuracy, rel_accuracy = accuracy_vs_cs()
# Out:
# Processing c_s = 0.0
# Processing c_s = 0.01
# Processing c_s = 0.02
# Processing c_s = 0.03
# Processing c_s = 0.04
# Processing c_s = 0.05
# Processing c_s = 0.06
# Processing c_s = 0.07
# Processing c_s = 0.08
# Processing c_s = 0.09
# Processing c_s = 0.1
# Processing c_s = 0.11
# Processing c_s = 0.12
# Processing c_s = 0.13
# Processing c_s = 0.14
# Processing c_s = 0.15
# Processing c_s = 0.16
# Processing c_s = 0.17
# Processing c_s = 0.18
# Processing c_s = 0.19
# Processing c_s = 0.2
# Processing c_s = 0.21
# Processing c_s = 0.22
# Processing c_s = 0.23
# Processing c_s = 0.24
# Processing c_s = 0.25
# Processing c_s = 0.26
# Processing c_s = 0.27
# Processing c_s = 0.28
# Processing c_s = 0.29
# Processing c_s = 0.3
# Processing c_s = 0.31
# Processing c_s = 0.32
# Processing c_s = 0.33
# Processing c_s = 0.34
# Processing c_s = 0.35000000000000003
# Processing c_s = 0.36
# Processing c_s = 0.37
# Processing c_s = 0.38
# Processing c_s = 0.39
# Processing c_s = 0.4
# Processing c_s = 0.41000000000000003
# Processing c_s = 0.42
# Processing c_s = 0.43
# Processing c_s = 0.44
# Processing c_s = 0.45
# Processing c_s = 0.46
# Processing c_s = 0.47000000000000003
# Processing c_s = 0.48
# Processing c_s = 0.49
# Processing c_s = 0.5
# Processing c_s = 0.51
# Processing c_s = 0.52
# Processing c_s = 0.53
# Processing c_s = 0.54
# Processing c_s = 0.55
# Processing c_s = 0.56
# Processing c_s = 0.5700000000000001
# Processing c_s = 0.58
# Processing c_s = 0.59
# Processing c_s = 0.6
# Processing c_s = 0.61
# Processing c_s = 0.62
# Processing c_s = 0.63
# Processing c_s = 0.64
# Processing c_s = 0.65
# Processing c_s = 0.66
# Processing c_s = 0.67
# Processing c_s = 0.68
# Processing c_s = 0.6900000000000001
# Processing c_s = 0.7000000000000001
# Processing c_s = 0.71
# Processing c_s = 0.72
# Processing c_s = 0.73
# Processing c_s = 0.74
# Processing c_s = 0.75
# Processing c_s = 0.76
# Processing c_s = 0.77
# Processing c_s = 0.78
# Processing c_s = 0.79
# Processing c_s = 0.8
# Processing c_s = 0.81
# Processing c_s = 0.8200000000000001
# Processing c_s = 0.8300000000000001
# Processing c_s = 0.84
# Processing c_s = 0.85
# Processing c_s = 0.86
# Processing c_s = 0.87
# Processing c_s = 0.88
# Processing c_s = 0.89
# Processing c_s = 0.9
# Processing c_s = 0.91
# Processing c_s = 0.92
# Processing c_s = 0.93
# Processing c_s = 0.9400000000000001
# Processing c_s = 0.9500000000000001
# Processing c_s = 0.96
# Processing c_s = 0.97
# Processing c_s = 0.98
# Processing c_s = 0.99

# %%
# Plot absolute and relative error as a function of c_s

fig, ax1 = plt.subplots()

ax1.set_xlabel("c_s")
ax1.set_ylabel("Absolute Error", color="tab:blue")
ax1.plot(cs_values, abs_accuracy, color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.set_ylabel("Relative Error", color="tab:red")
ax2.plot(cs_values, rel_accuracy, color="tab:red")
ax2.tick_params(axis="y", labelcolor="tab:red")
